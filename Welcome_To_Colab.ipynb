# %% [markdown]
# <a href="https://colab.research.google.com/github/jellis451-code/CSC121-Spring2026-Assignments-Week13/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: journal.py
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS

# write_entry(filename, entry)
#   open file in append mode ('a')
#   write entry + "\n" so each entry starts on a new line
#   close file

# read_journal(filename)
#   open file in read mode ('r')
#   read all contents
#   print contents
#   close file

# PROGRAM LOGIC
# while loop runs until user types "quit"
# ask user: (W)rite, (R)ead, or (Q)uit
# if W:
#   ask for entry
#   call write_entry
# if R:
#   call read_journal
# if Q:
#   exit loop
